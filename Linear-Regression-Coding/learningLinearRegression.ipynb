# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#print(plt.style.available)
plt.style.use("seaborn-v0_8-white")
import numpy as np

# %%
rng = np.random.RandomState(1)
x = 10 * rng.rand(50)
y = 2 * x - 5 + rng.randn(50)
plt.scatter(x, y)

# %%
# this is a test

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression(fit_intercept=True)

model.fit(x[:, np.newaxis], y)

xFit = np.linspace(0, 10, 1000) 
yFit = model.predict(xFit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xFit, yFit)

# %%
print("Model slope:    ", model.coef_[0])
print("Model intercept:", model.intercept_)
# Out:
# Model slope:     2.0272088103606944
# Model intercept: -4.9985770855532

# %%
rng = np.random.RandomState(1)
X = 10 * rng.rand(100, 3)
Y = 0.5 + np.dot(X, [1.5, -2, 1.])

model.fit(X,Y)
print(model.intercept_)
print(model.coef_)
# Out:
# 0.5000000000000033
# [ 1.5 -2.   1. ]

# %%
from sklearn.preprocessing import PolynomialFeatures

x = np.array([2,3,4])

poly = PolynomialFeatures(3, include_bias=False)
poly.fit_transform(x[:, None])
# Out:
# array([[ 2.,  4.,  8.],
#        [ 3.,  9., 27.],
#        [ 4., 16., 64.]])

# %%
from sklearn.pipeline import make_pipeline

polyModel = make_pipeline(PolynomialFeatures(7), LinearRegression())

# %%
rng = np.random.RandomState(1)
x = 10 * rng.rand(50)
y = np.sin(x) + 0.1 * rng.randn(50)

polyModel.fit(x[:, np.newaxis], y)
yFit = polyModel.predict(xFit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xFit, yFit)

# %%
import pandas as pd

file = "PremierLeagueSeason2024.csv"
read = pd.read_csv(file)

xVal = np.array(read["goals_scored"]).reshape(-1, 1)
yVal = read["goals_conceded"]


plt.xlabel("Goals Scored", size=15)
plt.ylabel("Goals Conceded", size=15)
plt.title("Goal's scored vs Goal' s Conceded")


from sklearn.linear_model import LinearRegression

model = LinearRegression(fit_intercept=True)

model.fit(xVal, yVal)

xFit = np.linspace(xVal.min(), xVal.max(), 1000).reshape(-1, 1)
yFit = model.predict(xFit)

plt.scatter(xVal, yVal)
plt.plot(xFit, yFit)

# %%
newData = "first_half.csv" # I got a new dataset as the above data was not good enough due to the size of the csv file

read = pd.read_csv(newData)

x = read[["X"]]
y = read[["Y"]]
other = read[["GameId", "PlayId", "Team"]]


details = {
    'X': ['x'],
    'Y': ['y']
}


# 682155 / 2 = drop;


i = 0
totalRows = 682155


df = pd.read_csv(newData, low_memory=False)
# row_indices = df.index[-1]
# s = row_indices / 2


# total = round(s)


# dropData = pd.DataFrame(details, columns=['x', 'y'], index=['1', '2'])

# drop = pd.DataFrame(details, columns=['x', 'y', 'other'], index=[total])


# Calculate the halfway point
halfway_index = totalRows // 2


less = round(halfway_index / 2)


# print("halfway_index", halfway_index)

# Drop the second half of the dataframe
df_first_half = df.iloc[:less]
# print("df_first_half", df_first_half)

newX = df_first_half[["X"]]
newY = df_first_half[["Y"]]

# print("newX value has: ", newX)

plt.title("NFL players X and Y position")
plt.ylabel("Players Y Position", size=15)
plt.xlabel("Players X Position", size=15)
# plt.scatter(newX, newY)




from sklearn.linear_model import LinearRegression

model = LinearRegression(fit_intercept=True)

model.fit(newX, newY)

xFit = np.linspace(newX.min(), newX.max(), 1000).reshape(-1, 1)
yFit = model.predict(xFit)

plt.scatter(newX, newY)
plt.plot(xFit, yFit)




# plt.plot(newX)
# plt.plot(newY)


# Save the new dataframe to a new file or continue with further processing
# df_first_half.to_csv('6th_half.csv', index=False)


# for i in range(total):
#     total -= 1
#     print(drop)
    # print("index: ", i)



# print("dropData has:\n", dropData)
# print("drop has:\n", drop)


# new = dropData.drop(['1']) # i want to do this multiple times.......
# for i in range(totalRows):
#     dropData = pd.DataFrame(details, columns=['x', 'y'], index=[i])
#     new = dropData.drop(i)
# Out:
# C:\Users\Kylek\AppData\Local\Temp\ipykernel_20880\2173638849.py:3: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   read = pd.read_csv(newData)
# C:\Users\Kylek\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# print(help(dropData.drop('3')))

# %%
# dropData

# %%
df = pd.read_csv(newData, nrows=682156)

# Print the resulting DataFrame
# print(df)

# print(df.index)



# Load the entire CSV into a DataFrame
df = pd.read_csv(newData, low_memory=False)

# Get the row indices from 0 to the end of the file
row_indices = df.index[-1]

# Print the row indices
print(row_indices)
# Out:
# C:\Users\Kylek\AppData\Local\Temp\ipykernel_20880\2163855592.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(newData, nrows=682156)
# 341076

# %%
plt.scatter(x, y)

# %%
print(read)
# Out:
#             GameId          PlayId  Team      X      Y     S     A   Dis  \
# 0       2017090700  20170907000118  away  73.91  34.84  1.69  1.13  0.40
# 1       2017090700  20170907000118  away  74.67  32.64  0.42  1.35  0.01
# 2       2017090700  20170907000118  away  74.00  33.20  1.22  0.59  0.31
# 3       2017090700  20170907000118  away  71.46  27.70  0.42  0.54  0.02
# 4       2017090700  20170907000118  away  69.32  35.42  1.82  2.43  0.16
# ...            ...             ...   ...    ...    ...   ...   ...   ...
# 341072  2018101404  20181014041827  away  83.62   8.80  3.64  1.16  0.36
# 341073  2018101404  20181014041827  away  82.75  29.40  3.05  1.54  0.33
# 341074  2018101404  20181014041827  away  87.78  29.79  5.03  2.75  0.49
# 341075  2018101404  20181014041827  away  89.15  30.42  2.14  3.51  0.19
# 341076  2018101404  20181014041827  away  83.22  14.22  3.86  1.06  0.38
#
#         Orientation     Dir  ...  Week            Stadium  \
# ...

# %%
bBallData = "cbb.csv"
read = pd.read_csv(bBallData)

gamesPlayed = read[["G"]]
gamesWon = read[["W"]]


plt.title("Basketball games won vs played")
plt.ylabel("Games Won", size=15)
plt.xlabel("Games Played", size=15)


rows = read.index[-1] # total rows in the csv file
rounded = round(rows/2) # here I split the rows in half and round the answer


from sklearn.linear_model import LinearRegression

model = LinearRegression(fit_intercept=True)

model.fit(gamesPlayed/rounded, gamesWon/rounded)

games = np.linspace(gamesPlayed.min(), gamesPlayed.max(), 1000).reshape(-1, 1)
won = model.predict(games)


plt.scatter(gamesPlayed, gamesWon, alpha=0.6, s=50, label="Data from csv")
plt.plot(games, won, color="red", linestyle="--", linewidth=2, label="Linear Regression")

plt.grid(True, linestyle="--", alpha=0.7)

plt.legend()
# Out:
# C:\Users\Kylek\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
